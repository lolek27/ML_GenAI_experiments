# %% [markdown]
# #RAG and TruLens Evaluation - advanced techniques with auto-merging retrieval
#
# RAG - retrieval augmented generation - is an antidote for contemporary LLMs hallucinations. However, naive RAG is prone to making up facts and not leveraging the knowledge base it has access to. In this notebook we will present techniques for efficient managing available knowledge, advanced retrieval techniqes and reranking capabilities. We base our design on:
#  - Llama_index's retrieval module utilizing auto-mergin retrieval technique for more efficient context retrieval,
#  - Llama_index's default VectorStoreIndex, which uses an in-memory SimpleVectorStore that's initialized as part of the default storage context,
#  - Llama2-13B as the LLM answer generator
#  -MTEB's leading sentence embeddings (BAAI/bge-base-en-v1.5)
#  - SentenceTransformers based reranker "BAAI/bge-reranker-base"
#
# **Auto-merging retrieval** technique setups the chunks of tokens in parent-children type of hierarchy (with number of levels controlled by a parameter). During retrieval, if the majority of chunks in a given parent set is relevant to the query, the parent chunk is returned instead, allowing for more extended context to be fed to the LLM.
#
# Furthermore, evaluation of different RAG setups will be performed with the use TruLens RAG benchmark, which employs OpenAI as reasoning engine to evaluate generated outputs with respect to three main components (so called RAG Triad):
# - Answer Relevance
# - Context Relevance
# - Groundedness
#
# For this exercise I will use 290 page pdf book "Building Knowledge Graphs - A Practitioner's Guide" by J. Barrasa and J. Webber (compliments of neo4j).

# %%
# !pip install -qU \
  transformers \
  sentence-transformers \
  accelerate \
  langchain \
  bitsandbytes \
  llama_index \
  trulens_eval \
  pypdf

# %% [markdown]
# #1. Get Knowledge Graph Practicioner guide

# %%
from llama_index import SimpleDirectoryReader

documents = SimpleDirectoryReader(
    input_files=["/content/drive/MyDrive/ML/data/RAG/Building-Knowledge-Graphs-Practitioner's-Guide-OReilly-book.pdf"]
).load_data()

from llama_index import Document

document = Document(text="\n\n".join([doc.text for doc in documents]))

# %%
document.text[10000:20000]
# Out:
# '                   130\nMetadata Graph Example                                                                                             130\nQuerying the Metadata Graph Model                                                                         131\nUsing Relationships to Connect Data and Metadata                                                133\nSummary                                                                                                                         134\n9.Identity Knowledge Graphs. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  135\nKnowing Y our Customer                                                                                              135\nWhen Does the Problem Appear?                                                                               136\nGraph-Based Entity Resolution Step by Step                                                             137\nData Preparation                                                                                                        138\nEntity Matching                                                                                                          141\nBuild/Update a Persisted Record of Master Entities                                             145\nWorking with Unstructured Data                                                                                149\nSummary                                                                                                                         154\n10. Pattern Detection Knowledge Graphs. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  155\nFraud Detection                                                                                                             155\nFirst-Party Fraud                                                                                                        156\nUncovering Fraud from Data                                                                                   157\nFraud Rings                                                                                                                 159\nInnocent Bystanders                                                                                                  162\nOperationalizing the Fraud Detection Knowledge Graph                                   164\nSkills Matching                                                                                                               165\nOrganizational Knowledge Graph                                                                           165\nSkills Knowledge Graph                                                                                            167\nExpertise Knowledge Graph                                                                                     170\nIndividual Career Growth                                                                                         173\nOrganizational Planning                                                                                           175\nPredicting Organizational Performance                                                                 179\nSummary                                                                                                                         186\n11. Dependency Knowledge Graphs. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  187\nDependencies as a Graph                                                                                              187\nAdvanced Graph Dependency Modeling                                                                   190\nQualified Dependencies                                                                                            190\nSemantics of Multidependency                                                                                193\nImpact Propagation with Cypher                                  ...

# %% [markdown]
# Setup the auto-merging retrieval and test

# %%
from llama_index.node_parser import HierarchicalNodeParser
from llama_index.node_parser import get_leaf_nodes

# create the hierarchical node parser w/ default settings
node_parser = HierarchicalNodeParser.from_defaults(
    chunk_sizes=[2048, 512, 128]
)
nodes = node_parser.get_nodes_from_documents([document])

leaf_nodes = get_leaf_nodes(nodes)
print(leaf_nodes[300].text)
# Out:
# Some, but not all, of those relationships also have since  properties on them repre‐
# senting the date when the person began living in the place.

# %%
nodes_by_id = {node.node_id: node for node in nodes}

parent_node = nodes_by_id[leaf_nodes[300].parent_node.node_id]
print(parent_node.text)
# Out:
# Example 4-18. places_header.csv  contains the signature for Place  nodes
# :ID(Place), city, country
# Example 4-19. places1.csv  contains data for Place  nodes
# 143,Berlin,Germany
# Example 4-20. places2.csv  contains data for Place  nodes
# 244,London,UK
# To connect people and places, you need to have something like Example 4-21 , which
# contains relationships starting with Person  nodes and ending with Place  nodes.
# Some, but not all, of those relationships also have since  properties on them repre‐
# senting the date when the person began living in the place.

# %% [markdown]
# #3. Get LLama2-13B and Embeddings

# %% [markdown]
# ##3.1. Llama2-13B and Embeddings, setup the service context
#
# We load Llama2-13B, fitting it on a single 15GB RAM with the help of bitsandbytes quantization.

# %%
# %%time
from torch import cuda, bfloat16
import transformers
import torch


model_name = "meta-llama/Llama-2-13b-chat-hf"
# set quantization configuration using bitsandbytes lib
bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=bfloat16
)


hf_auth = os.environ.get('HF_API_KEY')
model_config = transformers.AutoConfig.from_pretrained(
    model_name,
    use_auth_token=hf_auth
)

model = transformers.AutoModelForCausalLM.from_pretrained(
    model_name,
    trust_remote_code=True,
    config=model_config,
    quantization_config=bnb_config,
    device_map='auto',
    use_auth_token=hf_auth
)
model.eval()

# %% [markdown]
# Let's select some decent embeddings model based on [HF's leaderboard](https://huggingface.co/spaces/mteb/leaderboard).

# %%
# %%time
import torch
from llama_index.llms import HuggingFaceLLM
from llama_index.prompts import PromptTemplate

# This will wrap the default prompts that are internal to llama-index
# taken from https://huggingface.co/Writer/camel-5b-hf
query_wrapper_prompt = PromptTemplate(
    "Below is an instruction that describes a task. "
    "Write a response that appropriately completes the request.\n\n"
    "### Instruction:\n{query_str}\n\n### Response:"
)

model_name = "meta-llama/Llama-2-13b-chat-hf"
tokenizer = transformers.AutoTokenizer.from_pretrained(
    model_name,
    use_auth_token=hf_auth
)

llm = HuggingFaceLLM(
    model=model,
    tokenizer=tokenizer,
    context_window=2048,
    max_new_tokens=512,
    generate_kwargs={
        "temperature": 0.01,
        "repetition_penalty": 1.1 },
    query_wrapper_prompt=query_wrapper_prompt
)

from llama_index.embeddings import HuggingFaceEmbedding

embed_model = HuggingFaceEmbedding(model_name='BAAI/bge-base-en-v1.5')
# Out:
# config.json:   0%|          | 0.00/777 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# CPU times: user 1.1 s, sys: 1.1 s, total: 2.2 s
# Wall time: 3.86 s

# %% [markdown]
# ### 3.2 Build the index

# %%
from llama_index import VectorStoreIndex
from llama_index import ServiceContext, StorageContext

auto_merging_context = ServiceContext.from_defaults(
    llm=llm,
    embed_model=embed_model,
    node_parser=node_parser
)

storage_context = StorageContext.from_defaults()
storage_context.docstore.add_documents(nodes)

automerging_index = VectorStoreIndex(
    leaf_nodes, storage_context=storage_context, service_context=auto_merging_context
)

automerging_index.storage_context.persist(persist_dir="/content/drive/MyDrive/ML/data/RAG//merging_index")

# %%
# This block of code is optional to check
# if an index file exist, then it will load it
# if not, it will rebuild it

import os
from llama_index import VectorStoreIndex, StorageContext, load_index_from_storage
from llama_index import load_index_from_storage

if not os.path.exists("/content/drive/MyDrive/ML/data/RAG//merging_index"):
     automerging_index = VectorStoreIndex(
            leaf_nodes,
            storage_context=storage_context,
            service_context=auto_merging_context
        )

    automerging_index.storage_context.persist(persist_dir="/content/drive/MyDrive/ML/data/RAG//merging_index")
else:
    automerging_index = load_index_from_storage(
        StorageContext.from_defaults(persist_dir="/content/drive/MyDrive/ML/data/RAG//merging_index"),
        service_context=auto_merging_context
    )

# %% [markdown]
# ###3.3. Define the retriever and run query engine

# %%
from llama_index.indices.postprocessor import SentenceTransformerRerank
from llama_index.retrievers import AutoMergingRetriever
from llama_index.query_engine import RetrieverQueryEngine

automerging_retriever = automerging_index.as_retriever(
    similarity_top_k=12
)

retriever = AutoMergingRetriever(
    automerging_retriever,
    automerging_index.storage_context,
    verbose=True
)

rerank = SentenceTransformerRerank(top_n=6, model="BAAI/bge-reranker-base")

auto_merging_engine = RetrieverQueryEngine.from_args(
    automerging_retriever, node_postprocessors=[rerank]
)
# Out:
# config.json:   0%|          | 0.00/799 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/443 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/279 [00:00<?, ?B/s]

# %%
auto_merging_response = auto_merging_engine.query(
    "How did Meredith Corporation consolidate their client profiles and by what number did they reduce duplication among them?"
)
from llama_index.response.notebook_utils import display_response

display_response(auto_merging_response)
# Out:
# **`Final Response:`** Meredith Corporation consolidated their client profiles by using the WCC algorithm to identify unique sub-graphs within the larger graph. This allowed them to connect and analyze data from different sources. By implementing this algorithm, they were able to reduce duplication among client profiles. The exact number by which they reduced duplication is not mentioned in the given context.

# %% [markdown]
# #4. Testing the Auto-merging retriever setup

# %%
window_response = auto_merging_engine.query(
    "How can knowledge graphs be used in entity resolution problems where there are no strong identifiers?"
)
display_response(window_response)
# Out:
# **`Final Response:`** Knowledge graphs can be used in entity resolution problems where there are no strong identifiers by leveraging the power of graph algorithms and techniques. By using knowledge graphs, a set of weak identifiers can be aggregated into a strong identifier. This means that even if there are no strong identifiers available, the relationships and connections within the knowledge graph can be used to determine if two records represent the same real-world thing. The graph algorithms can analyze the relationships, similarities, and patterns within the knowledge graph to make informed decisions about entity resolution. This approach allows for the integration of data from different systems and helps in reasoning whether a record in one system has a counterpart in another system.

# %%
window_response = auto_merging_engine.query(
    "Explain how identity graph improved consumer insight for Meredith Corporation?"
)
display_response(window_response)
# Out:
# **`Final Response:`** The identity graph improved consumer insight for Meredith Corporation by allowing them to better understand their customers. By analyzing data over time and connecting it, rather than just looking at individual cookies, Meredith was able to increase their understanding of a customer by 20 to 30%. This deeper understanding translated into significant revenue gains and better-served consumers. The average length of touch points also increased from 14 days with a cookie to 241 days with user profiles, and average visits increased from 4 per cookie to 23.8 per profile. Overall, the identity graph provided Meredith with a 360-degree view of their users, even for anonymous users, which helped them personalize content and improve the user experience.

# %%
window_response = auto_merging_engine.query(
    "What is a fraud-ring pattern and what are ways to detect it?"
)
display_response(window_response)
# Out:
# **`Final Response:`** A fraud-ring pattern refers to a network of individuals who collaborate to commit fraudulent activities, such as identity theft or financial fraud. These individuals often create synthetic identities by using shared phone numbers and addresses to make their fraudulent activities harder to detect.
#
# One way to detect a fraud-ring pattern is by using a knowledge graph. By analyzing the relationships between individuals, phone numbers, and addresses, patterns can be identified. For example, if multiple individuals share the same phone number and address, it could indicate a potential fraud ring. Additionally, analyzing the path length between individuals and identifying repeated patterns can help in detecting fraud rings.
#
# It is important to note that not all linked identities may be fraudsters, as legitimate individuals can also share addresses and phone numbers. Therefore, it requires a combination of human expertise and machine learning to accurately identify and detect fraud-ring patterns.

# %% [markdown]
# Let's create a function to encapsulate all the above steps:

# %%
import os
from torch import cuda, bfloat16
import transformers
import torch
from llama_index.node_parser import HierarchicalNodeParser
from llama_index.node_parser import get_leaf_nodes
from llama_index import ServiceContext, VectorStoreIndex, StorageContext
from llama_index.indices.postprocessor import MetadataReplacementPostProcessor
from llama_index.indices.postprocessor import SentenceTransformerRerank
from llama_index import load_index_from_storage
from llama_index.prompts import PromptTemplate
from llama_index.embeddings import HuggingFaceEmbedding
from llama_index.llms import HuggingFaceLLM

def init_rag_llms(model_name = "meta-llama/Llama-2-13b-chat-hf", embed_model_name='BAAI/bge-base-en-v1.5'):

    # set quantization configuration using bitsandbytes lib
    bnb_config = transformers.BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type='nf4',
        bnb_4bit_use_double_quant=True,
        bnb_4bit_compute_dtype=bfloat16
    )


    hf_auth = os.environ.get('HF_API_KEY')
    model_config = transformers.AutoConfig.from_pretrained(
        model_name,
        use_auth_token=hf_auth
    )

    model = transformers.AutoModelForCausalLM.from_pretrained(
        model_name,
        trust_remote_code=True,
        config=model_config,
        quantization_config=bnb_config,
        device_map='auto',
        use_auth_token=hf_auth
    )
    model.eval()

    tokenizer = transformers.AutoTokenizer.from_pretrained(
        model_name,
        use_auth_token=hf_auth
    )

    # This will wrap the default prompts that are internal to llama-index
    # taken from https://huggingface.co/Writer/camel-5b-hf
    query_wrapper_prompt = PromptTemplate(
        "Below is an instruction that describes a task. "
        "Write a response that appropriately completes the request.\n\n"
        "### Instruction:\n{query_str}\n\n### Response:"
    )


    llm = HuggingFaceLLM(
        model=model,
        tokenizer=tokenizer,
        context_window=2048,
        max_new_tokens=512,
        generate_kwargs={
            "temperature": 0.01,
            "repetition_penalty": 1.1 },
        query_wrapper_prompt=query_wrapper_prompt
    )

    # loads 'intfloat/e5-base-v2'
    embed_model = HuggingFaceEmbedding(model_name=embed_model_name)
    return llm, embed_model


import os

from llama_index import (
    ServiceContext,
    StorageContext,
    VectorStoreIndex,
    load_index_from_storage,
)
from llama_index.node_parser import HierarchicalNodeParser
from llama_index.node_parser import get_leaf_nodes
from llama_index import StorageContext, load_index_from_storage
from llama_index.retrievers import AutoMergingRetriever
from llama_index.indices.postprocessor import SentenceTransformerRerank
from llama_index.query_engine import RetrieverQueryEngine


def build_automerging_index(
    documents,
    llm,
    embed_model,
    save_dir="merging_index",
    chunk_sizes=None,
):
    chunk_sizes = chunk_sizes or [2048, 512, 128]
    node_parser = HierarchicalNodeParser.from_defaults(chunk_sizes=chunk_sizes)
    nodes = node_parser.get_nodes_from_documents(documents)
    leaf_nodes = get_leaf_nodes(nodes)
    merging_context = ServiceContext.from_defaults(
        llm=llm,
        embed_model=embed_model,
    )
    storage_context = StorageContext.from_defaults()
    storage_context.docstore.add_documents(nodes)

    if not os.path.exists(save_dir):
        automerging_index = VectorStoreIndex(
            leaf_nodes, storage_context=storage_context, service_context=merging_context
        )
        automerging_index.storage_context.persist(persist_dir=save_dir)
    else:
        automerging_index = load_index_from_storage(
            StorageContext.from_defaults(persist_dir=save_dir),
            service_context=merging_context,
        )
    return automerging_index


def get_automerging_query_engine(
    automerging_index,
    similarity_top_k=12,
    rerank_top_n=4,
):
    base_retriever = automerging_index.as_retriever(similarity_top_k=similarity_top_k)
    retriever = AutoMergingRetriever(
        base_retriever, automerging_index.storage_context, verbose=True
    )
    rerank = SentenceTransformerRerank(
        top_n=rerank_top_n, model="BAAI/bge-reranker-base"
    )
    auto_merging_engine = RetrieverQueryEngine.from_args(
        retriever, node_postprocessors=[rerank]
    )
    return auto_merging_engine

# %% [markdown]
# ##5. TruLens Evaluation
#
# We'll run TruLens evaluation based on the RAG triad evaluation criteria:
# - Context Relevance: how relevant is retrieved context to the query?
# - Answer Relevance: how relevant is generated answer to the query?
# - Groundedness: to what extent is the output grounded in retrieved context?
#
# We'll be testing two setups for auto-merging and comparing the TruLens recorder's scores.

# %%
eval_questions = ["Explain how identity graph improved consumer insight for Meredith Corporation",
"What is the claim meredith corporation is making wrt the identy graph methods they employed?",
"Explain how can knowledge graphs be employed to solve the entity matching problem",
"In entity resolution problems what are strong and weak identifier? Explain with examples from the text.",
"How can knowledge graphs be used in entity resolution problems where there are no strong identifiers",
"List steps to designing a record deduplication solution using identity graphs",
"What are the challenges of working with unstructured data in entity resolution problem and how can they be addressed with graph-based solution",
"What are the common use cases where deduplication of data appear?",
"How can you employ graph-based solution for fraud detection?",
"What is a fraud-ring pattern and what are ways to detect it?",
"What are some pitfalls when detecting fraud ring and how to avoid them?",
"Explain how can knowledge graphs help to match skillsets of employers in an organization with particular project's needs"]

# %%
llm, embed_model = init_rag_llms(embed_model_name='BAAI/bge-base-en-v1.5')

# %% [markdown]
# We'll use tenacity to delay some of the calls to OpenAI apis in order to avoid rate exceed exceptions from the API.

# %%
# !pip install tenacity

# %%
from trulens_eval.feedback import Groundedness
from llama_index.response.notebook_utils import display_response
from tenacity import retry, stop_after_attempt, wait_exponential

from trulens_eval import (
    Feedback,
    TruLlama,
    OpenAI
)
from trulens_eval import Tru

@retry(stop=stop_after_attempt(10), wait=wait_exponential(multiplier=1, min=4, max=10))
def call_tru_query_engine(query_engine, prompt):
    return query_engine.query(prompt)


def run_evals(eval_questions, tru_recorder, query_engine):
    for question in eval_questions:
        with tru_recorder as recording:
            response = call_tru_query_engine(query_engine, question)  #query_engine.query(question)


def get_prebuilt_trulens_recorder(query_engine, app_id):
    openai = OpenAI()

    qa_relevance = (
        Feedback(openai.relevance_with_cot_reasons, name="Answer Relevance")
        .on_input_output()
    )

    qs_relevance = (
        Feedback(openai.relevance_with_cot_reasons, name = "Context Relevance")
        .on_input()
        .on(TruLlama.select_source_nodes().node.text)
        .aggregate(np.mean)
    )

    grounded = Groundedness(groundedness_provider=openai)

    groundedness = (
        Feedback(grounded.groundedness_measure_with_cot_reasons, name="Groundedness")
            .on(TruLlama.select_source_nodes().node.text)
            .on_output()
            .aggregate(grounded.grounded_statements_aggregator)
    )

    feedbacks = [qa_relevance, qs_relevance, groundedness]
    tru_recorder = TruLlama(
        query_engine,
        app_id=app_id,
        feedbacks=feedbacks
    )
    return tru_recorder

# %%
from trulens_eval import Tru
import numpy as np

Tru().reset_database()
# Out:
# 🦑 Tru initialized with db url sqlite:///default.sqlite .
# 🛑 Secret keys may be written to the database. See the `database_redact_keys` option of `Tru` to prevent this.

# %% [markdown]
# ##**5.1 Using two layer tree**

# %%
from llama_index.llms import OpenAI

auto_merging_index_2 = build_automerging_index(
    [document],
    llm=llm,
    embed_model=embed_model,
    chunk_sizes=[2048,512],
    save_dir="/content/drive/MyDrive/ML/data/RAG/merging_index_2",
)
auto_merging_engine_2 = get_automerging_query_engine(
    auto_merging_index_2,
    similarity_top_k=12,
    rerank_top_n=6,
)

# %%
tru_recorder_2 = get_prebuilt_trulens_recorder(
    auto_merging_engine_2,
    app_id ='app_2'
)
# Out:
# ✅ In Answer Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Answer Relevance, input response will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In Context Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Context Relevance, input response will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input source will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input statement will be set to __record__.main_output or `Select.RecordOutput` .

# %%
run_evals(eval_questions, tru_recorder_2, auto_merging_engine_2)

# %%
# Tru().run_dashboard()

# %%
Tru().get_records_and_feedback(app_ids=[])[0]
# Out:
#    app_id                                           app_json  \
# 0   app_2  {"tru_class_info": {"name": "TruLlama", "modul...
# 1   app_2  {"tru_class_info": {"name": "TruLlama", "modul...
# 2   app_2  {"tru_class_info": {"name": "TruLlama", "modul...
# 3   app_2  {"tru_class_info": {"name": "TruLlama", "modul...
# 4   app_2  {"tru_class_info": {"name": "TruLlama", "modul...
# 5   app_2  {"tru_class_info": {"name": "TruLlama", "modul...
# 6   app_2  {"tru_class_info": {"name": "TruLlama", "modul...
# 7   app_2  {"tru_class_info": {"name": "TruLlama", "modul...
# 8   app_2  {"tru_class_info": {"name": "TruLlama", "modul...
# 9   app_2  {"tru_class_info": {"name": "TruLlama", "modul...
# 10  app_2  {"tru_class_info": {"name": "TruLlama", "modul...
# 11  app_2  {"tru_class_info": {"name": "TruLlama", "modul...
#
#                                                  type  \
# 0   RetrieverQueryEngine(llama_index.query_engine....
# 1   RetrieverQueryEngine(llama_index.query_engine....
# 2   RetrieverQueryEngine(llama_index.query_engine....
# 3   RetrieverQueryEngine(llama_index.query_engine....
# 4   RetrieverQueryEngine(llama_index.query_engine....
# 5   RetrieverQueryEngine(llama_index.query_engine....
# 6   RetrieverQueryEngine(llama_index.query_engine....
# 7   RetrieverQueryEngine(llama_index.query_engine....
# 8   RetrieverQueryEngine(llama_index.query_engine....
# 9   RetrieverQueryEngine(llama_index.query_engine....
# 10  RetrieverQueryEngine(llama_index.query_engine....
# 11  RetrieverQueryEngine(llama_index.query_engine....
#
#                                        record_id  \
# 0   record_hash_2aafff8f7366652393bd59c1c5cb8dd5
# 1   record_hash_654badb11a3f97942c69a7b1f44b30b7
# 2   record_hash_a77677ebcb5283fdb8386455cb0930e0
# 3   record_hash_7e55b18e4a5463d1f52c60fb56f34034
# 4   record_hash_488faf8e7db0ab5d3101f0730389bdc7
# 5   record_hash_6bd45613abebc1feed3b7fdf4580e347
# 6   record_hash_d5ccd1d617d8b4771731bc852be1a475
# 7   record_hash_850a4fdf8af0a3cae6c7e879ddca0ef3
# 8   record_hash_48063ccfb39d957cb214c074ceb128ad
# 9   record_hash_9478fa7f5c6abaa2a26a292101d2c179
# 10  record_hash_5b1685d6dd226aef07bb10dc88c02d12
# 11  record_hash_133c1fe49531cc9f7bd2e42d9ac7dccc
#
#                                                 input  \
# 0   "Explain how identity graph improved consumer ...
# 1   "What is the claim meredith corporation is mak...
# 2   "Explain how can knowledge graphs be employed ...
# 3   "In entity resolution problems what are strong...
# 4   "How can knowledge graphs be used in entity re...
# 5   "List steps to designing a record deduplicatio...
# 6   "What are the challenges of working with unstr...
# 7   "What are the common use cases where deduplica...
# 8   "How can you employ graph-based solution for f...
# 9   "What is a fraud-ring pattern and what are way...
# 10  "What are some pitfalls when detecting fraud r...
# 11  "Explain how can knowledge graphs help to matc...
#
#                                                output tags  \
# 0   "The identity graph improved consumer insight ...    -
# 1   "Meredith Corporation asserts that they employ...    -
# 2   "Knowledge graphs can be employed to solve the...    -
# 3   "In entity resolution problems, strong identif...    -
# 4   "Knowledge graphs can be used in entity resolu...    -
# 5   "The steps to designing a record deduplication...    -
# 6   "The challenges of working with unstructured d...    -
# 7   "Data deduplication commonly occurs in scenari...    -
# 8   "A graph-based solution for fraud detection ca...    -
# 9   "A fraud-ring pattern refers to a network of i...    -
# 10  "When detecting fraud rings, it is important t...    -
# 11  "Knowledge graphs can help match skillsets of ...    -
#
#                                           record_json  \
# 0   {"record_id": "record_hash_2aafff8f7366652393b...
# 1   {"record_id": "record_hash_654badb11a3f97942c6...
# 2   {"record_id": "record_hash_a77677ebcb5283fdb83...
# 3   {"record_id": "record_hash_7e55b18e4a5463d1f52...
# 4   {"record_id": "record_hash_488faf8e7db0ab5d310...
# 5   {"record_id": "record_hash_6bd45613abebc1feed3...
# 6   {"record_id": "record_hash_d5ccd1d617d8b477173...
# 7   {"record_id": "record_hash_850a4fdf8af0a3cae6c...
# 8   {"record_id": "record_hash_48063ccfb39d957cb21...
# 9   {"record_id": "record_hash_9478fa7f5c6abaa2a26...
# 10  {"record_id": "record_hash_5b1685d6dd226aef07b...
# 11  {"record_id": "record_hash_133c1fe49531cc9f7bd...
#
#                                             cost_json  \
# 0   {"n_requests": 2, "n_successful_requests": 2, ...
# 1   {"n_requests": 2, "n_successful_requests": 2, ...
# 2   {"n_requests": 3, "n_successful_requests": 3, ...
# 3   {"n_requests": 1, "n_successful_requests": 1, ...
# 4   {"n_requests": 3, "n_successful_requests": 3, ...
# 5   {"n_requests": 1, "n_successful_requests": 1, ...
# 6   {"n_requests": 1, "n_successful_requests": 1, ...
# 7   {"n_requests": 1, "n_successful_requests": 1, ...
# 8   {"n_requests": 2, "n_successful_requests": 2, ...
# 9   {"n_requests": 2, "n_successful_requests": 2, ...
# 10  {"n_requests": 2, "n_successful_requests": 2, ...
# 11  {"n_requests": 1, "n_successful_requests": 1, ...
#
#                                             perf_json  \
# 0   {"start_time": "2023-12-22T06:56:46.471574", "...
# 1   {"start_time": "2023-12-22T06:56:57.768849", "...
# 2   {"start_time": "2023-12-22T06:57:06.464791", "...
# 3   {"start_time": "2023-12-22T06:57:26.576373", "...
# 4   {"start_time": "2023-12-22T06:57:36.108111", "...
# 5   {"start_time": "2023-12-22T06:57:52.384026", "...
# 6   {"start_time": "2023-12-22T06:58:02.506656", "...
# 7   {"start_time": "2023-12-22T06:58:09.585343", "...
# 8   {"start_time": "2023-12-22T06:58:15.982497", "...
# 9   {"start_time": "2023-12-22T06:58:26.777003", "...
# 10  {"start_time": "2023-12-22T06:58:44.557013", "...
# 11  {"start_time": "2023-12-22T06:59:12.312388", "...
#
#                             ts  Answer Relevance  Context Relevance  \
# 0   2023-12-22T06:56:57.061067               1.0           0.000000
# 1   2023-12-22T06:57:05.761829               1.0           0.000000
# 2   2023-12-22T06:57:25.874331               1.0           0.033333
# 3   2023-12-22T06:57:35.261430               1.0           0.600000
# 4   2023-12-22T06:57:51.641368               1.0           0.233333
# 5   2023-12-22T06:58:01.819761               1.0           0.166667
# 6   2023-12-22T06:58:08.819511               1.0           0.250000
# 7   2023-12-22T06:58:15.248846               1.0           0.150000
# 8   2023-12-22T06:58:26.088644               1.0           0.750000
# 9   2023-12-22T06:58:43.755364               1.0           0.283333
# 10  2023-12-22T06:58:59.050277               1.0           0.033333
# 11  2023-12-22T06:59:27.849826               1.0           0.433333
#
#     Groundedness                             Answer Relevance_calls  \
# 0       0.820000  [{'args': {'prompt': 'Explain how identity gra...
# 1       1.000000  [{'args': {'prompt': 'What is the claim meredi...
# 2       1.000000  [{'args': {'prompt': 'Explain how can knowledg...
# 3       1.000000  [{'args': {'prompt': 'In entity resolution pro...
# 4       1.000000  [{'args': {'prompt': 'How can knowledge graphs...
# 5       0.833333  [{'args': {'prompt': 'List steps to designing ...
# 6       0.800000  [{'args': {'prompt': 'What are the challenges ...
# 7       2.300000  [{'args': {'prompt': 'What are the common use ...
# 8       1.000000  [{'args': {'prompt': 'How can you employ graph...
# 9            NaN  [{'args': {'prompt': 'What is a fraud-ring pat...
# 10           NaN  [{'args': {'prompt': 'What are some pitfalls w...
# 11           NaN  [{'args': {'prompt': 'Explain how can knowledg...
#
#                               Context Relevance_calls  \
# 0   [{'args': {'prompt': 'Explain how identity gra...
# 1   [{'args': {'prompt': 'What is the claim meredi...
# 2   [{'args': {'prompt': 'Explain how can knowledg...
# 3   [{'args': {'prompt': 'In entity resolution pro...
# 4   [{'args': {'prompt': 'How can knowledge graphs...
# 5   [{'args': {'prompt': 'List steps to designing ...
# 6   [{'args': {'prompt': 'What are the challenges ...
# 7   [{'args': {'prompt': 'What are the common use ...
# 8   [{'args': {'prompt': 'How can you employ graph...
# 9   [{'args': {'prompt': 'What is a fraud-ring pat...
# 10  [{'args': {'prompt': 'What are some pitfalls w...
# 11  [{'args': {'prompt': 'Explain how can knowledg...
#
#                                    Groundedness_calls  latency  total_tokens  \
# 0   [{'args': {'source': 'Example 9-22. Matching u...       10          5093
# 1   [{'args': {'source': 'Example 9-22. Matching u...        7          5021
# 2   [{'args': {'source': '. . . . . . . . . . . . ...       19          5746
# 3   [{'args': {'source': 'This is done through the...        8          2503
# 4   [{'args': {'source': 'In cases  where  the dat...       15          6845
# 5   [{'args': {'source': '| Chapter 9: Identity Kn...        9          4039
# 6   [{'args': {'source': 'In cases  where  the dat...        6          3871
# 7   [{'args': {'source': 'In cases  where  the dat...        5          3433
# 8   [{'args': {'source': '162 | Chapter 10: Patter...       10          4797
# 9                                                 NaN       16          4939
# 10                                                NaN       14          5359
# 11                                                NaN       15          3162
#
#     total_cost
# 0     0.007757
# 1     0.007609
# 2     0.008876
# 3     0.003852
# 4     0.010423
# 5     0.006167
# 6     0.005866
# 7     0.005201
# 8     0.007304
# 9     0.007621
# 10    0.008221
# 11    0.004810

# %%
Tru().get_records_and_feedback(app_ids=[])[0].to_csv("/content/drive/MyDrive/ML/data/RAG/automargin_2.csv")

# %%
import pandas as pd
automargin_2 = pd.read_csv("/content/drive/MyDrive/ML/data/RAG/automargin_2.csv")

# %%
# get average Answer Relevance, Context Relevance and Groundedness
avg_ar = automargin_2['Answer Relevance'].mean()
avg_cr = automargin_2['Context Relevance'].mean()
avg_grd = automargin_2['Groundedness'].mean()
(avg_ar, avg_cr, avg_grd)
# Out:
# (1.0, 0.24444444444444438, 1.0535185185185185)

# %% [markdown]
# Average Answer Relevance and Groundedness is high.

# %% [markdown]
# ##**5.2. Using three layer tree**

# %%
auto_merging_index_3 = build_automerging_index(
    documents,
    llm=llm,
    embed_model=embed_model,
    save_dir="merging_index_3",
    chunk_sizes=[2048,512,128],
)

auto_merging_engine_3 = get_automerging_query_engine(
    auto_merging_index_3,
    similarity_top_k=12,
    rerank_top_n=6,
)
# Out:
# config.json:   0%|          | 0.00/799 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/443 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/279 [00:00<?, ?B/s]

# %%
tru_recorder = get_prebuilt_trulens_recorder(
    auto_merging_engine_3,
    app_id ='app_3'
)
# Out:
# ✅ In Answer Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Answer Relevance, input response will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In Context Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Context Relevance, input response will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input source will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input statement will be set to __record__.main_output or `Select.RecordOutput` .

# %% [markdown]
# Test on one question:

# %%
window_response = auto_merging_engine_3.query(
    # "What is a fraud-ring pattern and what are ways to detect it?"
    "Explain how identity graph improved consumer insight for Meredith Corporation"
)
display_response(window_response)
# Out:
# > Merging 5 nodes into parent node.
# > Parent node id: dc3b6791-03bb-4f20-90f7-13c838507a3e.
# > Parent node text: From here on, the algorithm will continue to build the graph where the connected
# components yield...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 49db924e-5453-4b28-9012-d98998e0bcc8.
# > Parent node text: It created a virtuous cycle.
# Meredith commented, “We basically have increased our understanding o...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 63370965-cc4e-402e-9c87-6911d4c53751.
# > Parent node text: From here on, the algorithm will continue to build the graph where the connected
# components yield...
# **`Final Response:`** The identity graph implemented by Meredith Corporation improved consumer insight by consolidating and analyzing user data from various sources. By using the WCC algorithm to identify unique sub-graphs within the larger graph, Meredith was able to create more accurate and comprehensive user profiles. This allowed them to understand their customers better and personalize content based on their interests and preferences. As a result, the average length of touch points increased significantly, from 14 days with a cookie to 241 days with user profiles. The number of average visits also increased, indicating that users were returning more frequently. By gaining a high-definition view of user interests and preferences, Meredith was able to develop stronger models and deliver more relevant content, leading to increased user engagement and revenue gains.

# %%
window_response = auto_merging_engine_3.query(
    # "What is a fraud-ring pattern and what are ways to detect it?"
    "How did Meredith Corporation consolidate their client profiles and by what number did they reduce duplication among them?"
)
display_response(window_response)
# Out:
# > Merging 5 nodes into parent node.
# > Parent node id: dc3b6791-03bb-4f20-90f7-13c838507a3e.
# > Parent node text: From here on, the algorithm will continue to build the graph where the connected
# components yield...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 49db924e-5453-4b28-9012-d98998e0bcc8.
# > Parent node text: It created a virtuous cycle.
# Meredith commented, “We basically have increased our understanding o...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 63370965-cc4e-402e-9c87-6911d4c53751.
# > Parent node text: From here on, the algorithm will continue to build the graph where the connected
# components yield...
# **`Final Response:`** Meredith Corporation consolidated their client profiles by identifying unique sub-graphs within the larger graph using the WCC algorithm. They incorporated more than 20 months of user data from both first- and third-party sources, resulting in nearly 350 million profiles being consolidated into 163 million richer and more accurate profiles. This consolidation reduced duplication among the client profiles. The exact number by which duplication was reduced is not mentioned in the given context.

# %%
run_evals(eval_questions, tru_recorder, auto_merging_engine_3)
# Out:
# > Merging 5 nodes into parent node.
# > Parent node id: dc3b6791-03bb-4f20-90f7-13c838507a3e.
# > Parent node text: From here on, the algorithm will continue to build the graph where the connected
# components yield...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 49db924e-5453-4b28-9012-d98998e0bcc8.
# > Parent node text: It created a virtuous cycle.
# Meredith commented, “We basically have increased our understanding o...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 63370965-cc4e-402e-9c87-6911d4c53751.
# > Parent node text: From here on, the algorithm will continue to build the graph where the connected
# components yield...
#
# > Merging 5 nodes into parent node.
# > Parent node id: dc3b6791-03bb-4f20-90f7-13c838507a3e.
# > Parent node text: From here on, the algorithm will continue to build the graph where the connected
# components yield...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 49db924e-5453-4b28-9012-d98998e0bcc8.
# > Parent node text: It created a virtuous cycle.
# Meredith commented, “We basically have increased our understanding o...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 63370965-cc4e-402e-9c87-6911d4c53751.
# > Parent node text: From here on, the algorithm will continue to build the graph where the connected
# components yield...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 196e812b-3a52-4a29-868a-330f7ffcda72.
# > Parent node text: Summary
# Identity is a key pillar for connecting knowledge graphs to the real world. In this
# chapt...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 29e1392c-f930-4a97-ab2b-de50b6ddfc57.
# > Parent node text: Summary
# Identity is a key pillar for connecting knowledge graphs to the real world. In this
# chapt...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 31a221ae-4197-4a5f-a71c-4e76f483447d.
# > Parent node text: Things become even more problematic in the absence of strong identifiers. In those
# cases, you wil...
#
# > Merging 1 nodes into parent node.
# > Parent node id: cfe041cf-e6d5-435e-9d79-b3750a70f9c1.
# > Parent node text: It has had significant positive
# impact on Banking Circle’s fraud detection efforts. It has turned...
#
# > Merging 4 nodes into parent node.
# > Parent node id: bb92859e-fd8b-4754-b110-2949ebb852a6.
# > Parent node text: compelling fake identities to gain access to many lines of credit. Then operate them
# normally unt...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 673f989d-e7de-4a6d-9db8-07c0ce814fe9.
# > Parent node text: compelling fake identities to gain access to many lines of credit. Then operate them
# normally unt...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 58aea0bc-b9bc-4179-b024-e1551b161564.
# > Parent node text: graph to be rendered visually, as shown in Figure 10-20 , which can be a much more
# intuitive view...
#
# > Merging 1 nodes into parent node.
# > Parent node id: d6b95878-90e9-462a-bb6d-70c3e1b3ba65.
# > Parent node text: graph to be rendered visually, as shown in Figure 10-20 , which can be a much more
# intuitive view...

# %%
Tru().get_records_and_feedback(app_ids=[])[0]
# Out:
#    app_id                                           app_json  \
# 0   app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 1   app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 2   app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 3   app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 4   app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 5   app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 6   app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 7   app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 8   app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 9   app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 10  app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 11  app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 12  app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 13  app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 14  app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 15  app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 16  app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 17  app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 18  app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 19  app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 20  app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 21  app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 22  app_3  {"tru_class_info": {"name": "TruLlama", "modul...
# 23  app_3  {"tru_class_info": {"name": "TruLlama", "modul...
#
#                                                  type  \
# 0   RetrieverQueryEngine(llama_index.query_engine....
# 1   RetrieverQueryEngine(llama_index.query_engine....
# 2   RetrieverQueryEngine(llama_index.query_engine....
# 3   RetrieverQueryEngine(llama_index.query_engine....
# 4   RetrieverQueryEngine(llama_index.query_engine....
# 5   RetrieverQueryEngine(llama_index.query_engine....
# 6   RetrieverQueryEngine(llama_index.query_engine....
# 7   RetrieverQueryEngine(llama_index.query_engine....
# 8   RetrieverQueryEngine(llama_index.query_engine....
# 9   RetrieverQueryEngine(llama_index.query_engine....
# 10  RetrieverQueryEngine(llama_index.query_engine....
# 11  RetrieverQueryEngine(llama_index.query_engine....
# 12  RetrieverQueryEngine(llama_index.query_engine....
# 13  RetrieverQueryEngine(llama_index.query_engine....
# 14  RetrieverQueryEngine(llama_index.query_engine....
# 15  RetrieverQueryEngine(llama_index.query_engine....
# 16  RetrieverQueryEngine(llama_index.query_engine....
# 17  RetrieverQueryEngine(llama_index.query_engine....
# 18  RetrieverQueryEngine(llama_index.query_engine....
# 19  RetrieverQueryEngine(llama_index.query_engine....
# 20  RetrieverQueryEngine(llama_index.query_engine....
# 21  RetrieverQueryEngine(llama_index.query_engine....
# 22  RetrieverQueryEngine(llama_index.query_engine....
# 23  RetrieverQueryEngine(llama_index.query_engine....
#
#                                        record_id  \
# 0   record_hash_2e4e3c007cda3b8695094a5691666e7a
# 1   record_hash_b913781213daa2c263bb9de256a8171f
# 2   record_hash_5aeedc10e93f2098c510832831fd5ffa
# 3   record_hash_748a1743161737aaf53c1082ecac5e19
# 4   record_hash_fd1f5f6b50b4f08771576cff4ca00d46
# 5   record_hash_3ed68d43d35c89e8879af89113424372
# 6   record_hash_6f75e2348ff4c21141ea9dffa919054f
# 7   record_hash_9e426a4679be5c2e0fbd11dfa6049b53
# 8   record_hash_41e2911e5e11ee5075abdcd3bc56700d
# 9   record_hash_c091eec9d98a6d5ef902ac7bd4d0d997
# 10  record_hash_92319bd7dc4e0e025ef3310af99f2d57
# 11  record_hash_518874a1eb3056f15ac430d8b53ab3f9
# 12  record_hash_595162d081cb66b3fe3aff3ea594bc61
# 13  record_hash_bfd4625ae749661cc34bd25a8a838050
# 14  record_hash_ada27aa3cb027f8a047e62e6313e0ca6
# 15  record_hash_e2a9d0f724c29c500b9a30cce4f96e77
# 16  record_hash_d0151fffdae30930c2d8b46caaa90182
# 17  record_hash_2eb14bfec319a1f2919236f80c90e857
# 18  record_hash_1681e5f9d3ac712c7286ab6bf5071ba5
# 19  record_hash_0774ba4989d1206aa4b2a05bc3b6e40f
# 20  record_hash_88d4b2a05ff3aec1cad2e70999955517
# 21  record_hash_c359a1b60082dfc27014b89afab2ba2d
# 22  record_hash_9f2e46ad2f95bb7b7b4cbd8018ed3692
# 23  record_hash_a0f0e2de59a8219f20ff1ff8cd6390ed
#
#                                                 input  \
# 0   "Explain how identity graph improved consumer ...
# 1   "What is the claim meredith corporation is mak...
# 2   "Explain how can knowledge graphs be employed ...
# 3   "In entity resolution problems what are strong...
# 4   "How can knowledge graphs be used in entity re...
# 5   "List steps to designing a record deduplicatio...
# 6   "What are the challenges of working with unstr...
# 7   "What are the common use cases where deduplica...
# 8   "How can you employ graph-based solution for f...
# 9   "What is a fraud-ring pattern and what are way...
# 10  "What are some pitfalls when detecting fraud r...
# 11  "Explain how can knowledge graphs help to matc...
# 12  "Explain how identity graph improved consumer ...
# 13  "What is the claim meredith corporation is mak...
# 14  "Explain how can knowledge graphs be employed ...
# 15  "In entity resolution problems what are strong...
# 16  "How can knowledge graphs be used in entity re...
# 17  "List steps to designing a record deduplicatio...
# 18  "What are the challenges of working with unstr...
# 19  "What are the common use cases where deduplica...
# 20  "How can you employ graph-based solution for f...
# 21  "What is a fraud-ring pattern and what are way...
# 22  "What are some pitfalls when detecting fraud r...
# 23  "Explain how can knowledge graphs help to matc...
#
#                                                output tags  \
# 0   "The identity graph implemented by Meredith Co...    -
# 1   "Meredith Corporation claims that by using gra...    -
# 2   "Knowledge graphs can be employed to solve the...    -
# 3   "In entity resolution problems, strong identif...    -
# 4   "Knowledge graphs can be used in entity resolu...    -
# 5   "The steps to designing a record deduplication...    -
# 6   "The challenges of working with unstructured d...    -
# 7   "Some of the common use cases where deduplicat...    -
# 8   "Graph-based solutions for fraud detection can...    -
# 9   "A fraud-ring pattern refers to a network of i...    -
# 10  "Pitfalls when detecting fraud rings include t...    -
# 11  "Knowledge graphs can help match skillsets of ...    -
# 12  "The identity graph implemented by Meredith Co...    -
# 13  "Meredith Corporation claims that by using gra...    -
# 14  "Knowledge graphs can be employed to solve the...    -
# 15  "In entity resolution problems, strong identif...    -
# 16  "Knowledge graphs can be used in entity resolu...    -
# 17  "The steps to designing a record deduplication...    -
# 18  "The challenges of working with unstructured d...    -
# 19  "Some of the common use cases where deduplicat...    -
# 20  "Graph-based solutions for fraud detection can...    -
# 21  "A fraud-ring pattern refers to a network of i...    -
# 22  "Pitfalls when detecting fraud rings include t...    -
# 23  "Knowledge graphs can help match skillsets of ...    -
#
#                                           record_json  \
# 0   {"record_id": "record_hash_2e4e3c007cda3b86950...
# 1   {"record_id": "record_hash_b913781213daa2c263b...
# 2   {"record_id": "record_hash_5aeedc10e93f2098c51...
# 3   {"record_id": "record_hash_748a1743161737aaf53...
# 4   {"record_id": "record_hash_fd1f5f6b50b4f087715...
# 5   {"record_id": "record_hash_3ed68d43d35c89e8879...
# 6   {"record_id": "record_hash_6f75e2348ff4c21141e...
# 7   {"record_id": "record_hash_9e426a4679be5c2e0fb...
# 8   {"record_id": "record_hash_41e2911e5e11ee5075a...
# 9   {"record_id": "record_hash_c091eec9d98a6d5ef90...
# 10  {"record_id": "record_hash_92319bd7dc4e0e025ef...
# 11  {"record_id": "record_hash_518874a1eb3056f15ac...
# 12  {"record_id": "record_hash_595162d081cb66b3fe3...
# 13  {"record_id": "record_hash_bfd4625ae749661cc34...
# 14  {"record_id": "record_hash_ada27aa3cb027f8a047...
# 15  {"record_id": "record_hash_e2a9d0f724c29c500b9...
# 16  {"record_id": "record_hash_d0151fffdae30930c2d...
# 17  {"record_id": "record_hash_2eb14bfec319a1f2919...
# 18  {"record_id": "record_hash_1681e5f9d3ac712c728...
# 19  {"record_id": "record_hash_0774ba4989d1206aa4b...
# 20  {"record_id": "record_hash_88d4b2a05ff3aec1cad...
# 21  {"record_id": "record_hash_c359a1b60082dfc2701...
# 22  {"record_id": "record_hash_9f2e46ad2f95bb7b7b4...
# 23  {"record_id": "record_hash_a0f0e2de59a8219f20f...
#
#                                             cost_json  \
# 0   {"n_requests": 1, "n_successful_requests": 1, ...
# 1   {"n_requests": 1, "n_successful_requests": 1, ...
# 2   {"n_requests": 1, "n_successful_requests": 1, ...
# 3   {"n_requests": 1, "n_successful_requests": 1, ...
# 4   {"n_requests": 1, "n_successful_requests": 1, ...
# 5   {"n_requests": 1, "n_successful_requests": 1, ...
# 6   {"n_requests": 1, "n_successful_requests": 1, ...
# 7   {"n_requests": 1, "n_successful_requests": 1, ...
# 8   {"n_requests": 1, "n_successful_requests": 1, ...
# 9   {"n_requests": 1, "n_successful_requests": 1, ...
# 10  {"n_requests": 1, "n_successful_requests": 1, ...
# 11  {"n_requests": 1, "n_successful_requests": 1, ...
# 12  {"n_requests": 1, "n_successful_requests": 1, ...
# 13  {"n_requests": 1, "n_successful_requests": 1, ...
# 14  {"n_requests": 1, "n_successful_requests": 1, ...
# 15  {"n_requests": 1, "n_successful_requests": 1, ...
# 16  {"n_requests": 1, "n_successful_requests": 1, ...
# 17  {"n_requests": 1, "n_successful_requests": 1, ...
# 18  {"n_requests": 1, "n_successful_requests": 1, ...
# 19  {"n_requests": 1, "n_successful_requests": 1, ...
# 20  {"n_requests": 1, "n_successful_requests": 1, ...
# 21  {"n_requests": 1, "n_successful_requests": 1, ...
# 22  {"n_requests": 1, "n_successful_requests": 1, ...
# 23  {"n_requests": 1, "n_successful_requests": 1, ...
#
#                                             perf_json  \
# 0   {"start_time": "2023-12-22T09:31:24.370345", "...
# 1   {"start_time": "2023-12-22T09:31:32.093662", "...
# 2   {"start_time": "2023-12-22T09:31:37.661979", "...
# 3   {"start_time": "2023-12-22T09:31:44.066420", "...
# 4   {"start_time": "2023-12-22T09:31:52.655862", "...
# 5   {"start_time": "2023-12-22T09:31:59.021711", "...
# 6   {"start_time": "2023-12-22T09:32:08.987014", "...
# 7   {"start_time": "2023-12-22T09:32:19.605232", "...
# 8   {"start_time": "2023-12-22T09:32:23.819023", "...
# 9   {"start_time": "2023-12-22T09:32:30.413829", "...
# 10  {"start_time": "2023-12-22T09:32:38.773525", "...
# 11  {"start_time": "2023-12-22T09:32:44.603459", "...
# 12  {"start_time": "2023-12-22T09:36:53.493996", "...
# 13  {"start_time": "2023-12-22T09:37:00.554440", "...
# 14  {"start_time": "2023-12-22T09:37:06.184379", "...
# 15  {"start_time": "2023-12-22T09:37:12.273017", "...
# 16  {"start_time": "2023-12-22T09:37:20.760697", "...
# 17  {"start_time": "2023-12-22T09:37:27.253958", "...
# 18  {"start_time": "2023-12-22T09:37:34.162966", "...
# 19  {"start_time": "2023-12-22T09:37:42.570543", "...
# 20  {"start_time": "2023-12-22T09:37:46.863466", "...
# 21  {"start_time": "2023-12-22T09:37:53.184479", "...
# 22  {"start_time": "2023-12-22T09:37:59.915107", "...
# 23  {"start_time": "2023-12-22T09:38:05.695130", "...
#
#                             ts  Answer Relevance  Context Relevance  \
# 0   2023-12-22T09:31:31.295906               0.9           0.166667
# 1   2023-12-22T09:31:36.981355               1.0           0.300000
# 2   2023-12-22T09:31:43.305511               1.0           0.350000
# 3   2023-12-22T09:31:51.838702               1.0           0.316667
# 4   2023-12-22T09:31:58.249769               1.0           0.700000
# 5   2023-12-22T09:32:08.306549               1.0           0.300000
# 6   2023-12-22T09:32:18.891575               1.0           0.416667
# 7   2023-12-22T09:32:22.992541               1.0           0.433333
# 8   2023-12-22T09:32:29.641650               0.9           0.583333
# 9   2023-12-22T09:32:38.065697               0.9           0.300000
# 10  2023-12-22T09:32:43.875105               1.0           0.316667
# 11  2023-12-22T09:32:51.028882               0.9           0.516667
# 12  2023-12-22T09:36:59.788257               1.0           0.166667
# 13  2023-12-22T09:37:05.476798               1.0           0.316667
# 14  2023-12-22T09:37:11.479173               1.0           0.350000
# 15  2023-12-22T09:37:19.788612               1.0           0.350000
# 16  2023-12-22T09:37:26.502633               1.0           0.750000
# 17  2023-12-22T09:37:33.340006               1.0           0.300000
# 18  2023-12-22T09:37:41.861223               1.0           0.433333
# 19  2023-12-22T09:37:46.079740               1.0           0.450000
# 20  2023-12-22T09:37:52.398901               1.0           0.583333
# 21  2023-12-22T09:37:59.092644               1.0           0.300000
# 22  2023-12-22T09:38:04.858523               1.0           0.316667
# 23  2023-12-22T09:38:12.230348               1.0           0.450000
#
#     Groundedness                             Answer Relevance_calls  \
# 0       0.966667  [{'args': {'prompt': 'Explain how identity gra...
# 1       1.000000  [{'args': {'prompt': 'What is the claim meredi...
# 2       1.000000  [{'args': {'prompt': 'Explain how can knowledg...
# 3       0.811111  [{'args': {'prompt': 'In entity resolution pro...
# 4       1.000000  [{'args': {'prompt': 'How can knowledge graphs...
# 5       1.000000  [{'args': {'prompt': 'List steps to designing ...
# 6       1.000000  [{'args': {'prompt': 'What are the challenges ...
# 7       1.000000  [{'args': {'prompt': 'What are the common use ...
# 8       1.000000  [{'args': {'prompt': 'How can you employ graph...
# 9       1.000000  [{'args': {'prompt': 'What is a fraud-ring pat...
# 10      0.750000  [{'args': {'prompt': 'What are some pitfalls w...
# 11      1.000000  [{'args': {'prompt': 'Explain how can knowledg...
# 12      1.000000  [{'args': {'prompt': 'Explain how identity gra...
# 13      0.500000  [{'args': {'prompt': 'What is the claim meredi...
# 14      1.000000  [{'args': {'prompt': 'Explain how can knowledg...
# 15      0.850000  [{'args': {'prompt': 'In entity resolution pro...
# 16      1.000000  [{'args': {'prompt': 'How can knowledge graphs...
# 17      0.800000  [{'args': {'prompt': 'List steps to designing ...
# 18      0.842857  [{'args': {'prompt': 'What are the challenges ...
# 19      0.333333  [{'args': {'prompt': 'What are the common use ...
# 20      1.000000  [{'args': {'prompt': 'How can you employ graph...
# 21      1.000000  [{'args': {'prompt': 'What is a fraud-ring pat...
# 22      0.925000  [{'args': {'prompt': 'What are some pitfalls w...
# 23      1.000000  [{'args': {'prompt': 'Explain how can knowledg...
#
#                               Context Relevance_calls  \
# 0   [{'args': {'prompt': 'Explain how identity gra...
# 1   [{'args': {'prompt': 'What is the claim meredi...
# 2   [{'args': {'prompt': 'Explain how can knowledg...
# 3   [{'args': {'prompt': 'In entity resolution pro...
# 4   [{'args': {'prompt': 'How can knowledge graphs...
# 5   [{'args': {'prompt': 'List steps to designing ...
# 6   [{'args': {'prompt': 'What are the challenges ...
# 7   [{'args': {'prompt': 'What are the common use ...
# 8   [{'args': {'prompt': 'How can you employ graph...
# 9   [{'args': {'prompt': 'What is a fraud-ring pat...
# 10  [{'args': {'prompt': 'What are some pitfalls w...
# 11  [{'args': {'prompt': 'Explain how can knowledg...
# 12  [{'args': {'prompt': 'Explain how identity gra...
# 13  [{'args': {'prompt': 'What is the claim meredi...
# 14  [{'args': {'prompt': 'Explain how can knowledg...
# 15  [{'args': {'prompt': 'In entity resolution pro...
# 16  [{'args': {'prompt': 'How can knowledge graphs...
# 17  [{'args': {'prompt': 'List steps to designing ...
# 18  [{'args': {'prompt': 'What are the challenges ...
# 19  [{'args': {'prompt': 'What are the common use ...
# 20  [{'args': {'prompt': 'How can you employ graph...
# 21  [{'args': {'prompt': 'What is a fraud-ring pat...
# 22  [{'args': {'prompt': 'What are some pitfalls w...
# 23  [{'args': {'prompt': 'Explain how can knowledg...
#
#                                    Groundedness_calls  latency  total_tokens  \
# 0   [{'args': {'source': 'From here on, the algori...        6          1375
# 1   [{'args': {'source': 'From here on, the algori...        4          1292
# 2   [{'args': {'source': 'CHAPTER 13
# Talking to Yo...        5           890
# 3   [{'args': {'source': 'The higher the
# score, th...        7           963
# 4   [{'args': {'source': 'This problem commonly ar...        5           895
# 5   [{'args': {'source': 'Graph-Based Entity Resol...        9          1061
# 6   [{'args': {'source': 'This problem commonly ar...        9           927
# 7   [{'args': {'source': 'The process  is rarely  ...        3           916
# 8   [{'args': {'source': 'Using both
# subgraph-loca...        5           857
# 9   [{'args': {'source': 'compelling fake identiti...        7          1270
# 10  [{'args': {'source': 'It’s reasonably common a...        5           838
# 11  [{'args': {'source': 'It already serves to sur...        6          1057
# 12  [{'args': {'source': 'From here on, the algori...        6          1371
# 13  [{'args': {'source': 'From here on, the algori...        4          1279
# 14  [{'args': {'source': 'CHAPTER 13
# Talking to Yo...        5           890
# 15  [{'args': {'source': 'The higher the
# score, th...        7           967
# 16  [{'args': {'source': 'This problem commonly ar...        5           914
# 17  [{'args': {'source': 'Graph-Based Entity Resol...        6           951
# 18  [{'args': {'source': 'This problem commonly ar...        7           969
# 19  [{'args': {'source': 'The process  is rarely  ...        3           916
# 20  [{'args': {'source': 'Using both
# subgraph-loca...        5           855
# 21  [{'args': {'source': 'compelling fake identiti...        5          1212
# 22  [{'args': {'source': 'It’s reasonably common a...        4           840
# 23  [{'args': {'source': 'It already serves to sur...        6          1057
#
#     total_cost
# 0     0.002136
# 1     0.001976
# 2     0.001383
# 3     0.001533
# 4     0.001392
# 5     0.001710
# 6     0.001460
# 7     0.001390
# 8     0.001339
# 9     0.001994
# 10    0.001298
# 11    0.001655
# 12    0.002128
# 13    0.001950
# 14    0.001383
# 15    0.001541
# 16    0.001430
# 17    0.001490
# 18    0.001544
# 19    0.001390
# 20    0.001335
# 21    0.001877
# 22    0.001302
# 23    0.001655

# %%
Tru().get_records_and_feedback(app_ids=[])[0].to_csv("/content/drive/MyDrive/ML/data/RAG/automerging_3.csv")

# %%
# get average Answer Relevance, Context Relevance and Groundedness
import pandas as pd
automerging_3_pd = pd.read_csv("/content/drive/MyDrive/ML/data/RAG/automerging_3.csv")

avg_ar = automerging_3_pd['Answer Relevance'].mean()
avg_cr = automerging_3_pd['Context Relevance'].mean()
avg_grd = automerging_3_pd['Groundedness'].mean()
(avg_ar, avg_cr, avg_grd)
# Out:
# (0.9833333333333334, 0.39444444444444443, 0.9074570105820104)

# %% [markdown]
# For the setup with 3-leyers of node hierarchy RAG performs better, which is reflected in TruLens' triad metric: mean Answer Relevance, Context Relevance and Groundedness.
#
# **Summary**
# - setup with 3 levels of nodes gives better granularity when selecting context.
# - error analysis: after analyzing the weakest link (Context Relevance score) it was visible that often the low score was not indicative of RAG not performing well. It was rather the matter of several pieces of context extracted and only one of them being relevant to the matter in question (rerank_top_n=6 meaning 6 pieces of context were assessed). So the score for the mismatched chunks were 0, creating low average score for context relevance, but the LLM anyway used only the right piece of context, outputting correct answer that was also grounded well in the piece of context provided.
